# %%
import pandas as pd
import numpy as np

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
df = pd.read_csv("steam_games.csv")

# %%
df.head(5)
# Out:
#                                                  url types  \
# 0    https://store.steampowered.com/app/379720/DOOM/   app
# 1  https://store.steampowered.com/app/578080/PLAY...   app
# 2  https://store.steampowered.com/app/637090/BATT...   app
# 3    https://store.steampowered.com/app/221100/DayZ/   app
# 4  https://store.steampowered.com/app/8500/EVE_On...   app
#
#                             name  \
# 0                           DOOM
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                     BATTLETECH
# 3                           DayZ
# 4                     EVE Online
#
#                                         desc_snippet  \
# 0  Now includes all three premium DLC packs (Unto...
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2  Take command of your own mercenary outfit of '...
# 3  The post-soviet country of Chernarus is struck...
# 4  EVE Online is a community-driven spaceship MMO...
#
#                                       recent_reviews  \
# 0  Very Positive,(554),- 89% of the 554 user revi...
# 1  Mixed,(6,214),- 49% of the 6,214 user reviews ...
# 2  Mixed,(166),- 54% of the 166 user reviews in t...
# 3  Mixed,(932),- 57% of the 932 user reviews in t...
# 4  Mixed,(287),- 54% of the 287 user reviews in t...
#
#                                          all_reviews  release_date  \
# 0  Very Positive,(42,550),- 92% of the 42,550 use...  May 12, 2016
# 1  Mixed,(836,608),- 49% of the 836,608 user revi...  Dec 21, 2017
# 2  Mostly Positive,(7,030),- 71% of the 7,030 use...  Apr 24, 2018
# 3  Mixed,(167,115),- 61% of the 167,115 user revi...  Dec 13, 2018
# 4  Mostly Positive,(11,481),- 74% of the 11,481 u...   May 6, 2003
#
#              developer                                publisher  \
# 0          id Software    Bethesda Softworks,Bethesda Softworks
# 1     PUBG Corporation        PUBG Corporation,PUBG Corporation
# 2  Harebrained Schemes  Paradox Interactive,Paradox Interactive
# 3  Bohemia Interactive  Bohemia Interactive,Bohemia Interactive
# 4                  CCP                                  CCP,CCP
#
#                                         popular_tags  \
# 0  FPS,Gore,Action,Demons,Shooter,First-Person,Gr...
# 1  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# 2  Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# 3  Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# 4  Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
#
#                                         game_details  \
# 0  Single-player,Multi-player,Co-op,Steam Achieve...
# 1             Multi-player,Online Multi-Player,Stats
# 2  Single-player,Multi-player,Online Multi-Player...
# 3  Multi-player,Online Multi-Player,Steam Worksho...
# 4  Multi-player,Online Multi-Player,MMO,Co-op,Onl...
#
#                                            languages  achievements  \
# 0  English,French,Italian,German,Spanish - Spain,...          54.0
# 1  English,Korean,Simplified Chinese,French,Germa...          37.0
# 2                      English,French,German,Russian         128.0
# 3  English,French,Italian,German,Spanish - Spain,...           NaN
# 4                      English,German,Russian,French           NaN
#
#                                                genre  \
# 0                                             Action
# 1             Action,Adventure,Massively Multiplayer
# 2                          Action,Adventure,Strategy
# 3             Action,Adventure,Massively Multiplayer
# 4  Action,Free to Play,Massively Multiplayer,RPG,...
#
#                                     game_description  \
# 0   About This Game Developed by id software, the...
# 1   About This Game  PLAYERUNKNOWN'S BATTLEGROUND...
# 2   About This Game  From original BATTLETECH/Mec...
# 3   About This Game The post-soviet country of Ch...
# 4                                  About This Game
#
#                                       mature_content  \
# 0                                                NaN
# 1   Mature Content Description  The developers de...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                 minimum_requirements  \
# 0  Minimum:,OS:,Windows 7/8.1/10 (64-bit versions...
# 1  Minimum:,Requires a 64-bit processor and opera...
# 2  Minimum:,Requires a 64-bit processor and opera...
# 3  Minimum:,OS:,Windows 7/8.1 64-bit,Processor:,I...
# 4  Minimum:,OS:,Windows 7,Processor:,Intel Dual C...
#
#                             recommended_requirements original_price  \
# 0  Recommended:,OS:,Windows 7/8.1/10 (64-bit vers...         $19.99
# 1  Recommended:,Requires a 64-bit processor and o...         $29.99
# 2  Recommended:,Requires a 64-bit processor and o...         $39.99
# 3  Recommended:,OS:,Windows 10 64-bit,Processor:,...         $44.99
# 4  Recommended:,OS:,Windows 10,Processor:,Intel i...           Free
#
#   discount_price
# 0         $14.99
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %% [markdown]
# # Data Preparation

# %% [markdown]
# The data preparation I did is to prepare the features that have a potential to be an identifier of similarity between games. Basically these features contains information about the game such as description, rating, genre, and any information we can get. In this project, I used features like description, genre, rating, and another details about the game.

# %% [markdown]
# ## Types Games

# %%
df["types"].unique()
# Out:
# array(['app', 'bundle', 'sub', nan], dtype=object)

# %% [markdown]
# I am curious about this feature. Turns out, there are three different types of games in Steam. But, there is also nan type or null data.

# %%
df[(df["types"]!='app')& (df["types"]!='bundle')&(df["types"]!='sub')]
# Out:
#                                                     url types name  \
# 704                     https://store.steampowered.com/   NaN  NaN
# 35169  https://store.steampowered.com/digitalgiftcards/   NaN  NaN
#
#       desc_snippet recent_reviews all_reviews release_date developer  \
# 704            NaN            NaN         NaN          NaN       NaN
# 35169          NaN            NaN         NaN          NaN       NaN
#
#       publisher popular_tags game_details languages  achievements genre  \
# 704         NaN          NaN          NaN       NaN           NaN   NaN
# 35169       NaN          NaN          NaN       NaN           NaN   NaN
#
#       game_description mature_content minimum_requirements  \
# 704                NaN            NaN                  NaN
# 35169              NaN            NaN                  NaN
#
#       recommended_requirements original_price discount_price
# 704                        NaN         $29.99         $23.99
# 35169                      NaN            NaN            NaN

# %% [markdown]
# For the games that have no type, these games also did not have many information about theirself. Index 704 and 35169 does not have enough info to be analyzed, because most of the data of these rows are Null. So I drop it.

# %%
#drop types=nan
df = df.drop([704,35169])
df = df.reset_index()

# %% [markdown]
# ## Description

# %% [markdown]
# There are two columns that can be used as description games feature, these are `desc_snippet` and `game_description`. I need to compare between these two columns.

# %%
df[["desc_snippet","game_description"]]
# Out:
#                                             desc_snippet  \
# 0      Now includes all three premium DLC packs (Unto...
# 1      PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2      Take command of your own mercenary outfit of '...
# 3      The post-soviet country of Chernarus is struck...
# 4      EVE Online is a community-driven spaceship MMO...
# ...                                                  ...
# 40826                                                NaN
# 40827                                                NaN
# 40828                                                NaN
# 40829                                                NaN
# 40830  An RPG about a tribe exploring an ancient worl...
#
#                                         game_description
# 0       About This Game Developed by id software, the...
# 1       About This Game  PLAYERUNKNOWN'S BATTLEGROUND...
# 2       About This Game  From original BATTLETECH/Mec...
# 3       About This Game The post-soviet country of Ch...
# 4                                      About This Game
# ...                                                  ...
# 40826   About This Content Play "Ghost Division" by S...
# 40827   About This Content Play "Trippin’ on a Hole i...
# 40828   About This Content  Quests of Doom 4: A Midni...
# 40829   About This Content Get equipped with the stun...
# 40830   About This Game  An RPG about a tribe explori...
#
# [40831 rows x 2 columns]

# %%
df["desc_snippet"][1]
# Out:
# "PLAYERUNKNOWN'S BATTLEGROUNDS is a battle royale shooter that pits 100 players against each other in a struggle for survival. Gather supplies and outwit your opponents to become the last person standing."

# %%
df["game_description"][1]
# Out:
# " About This Game  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle royale shooter that pits 100 players against each other in a struggle for survival. Gather supplies and outwit your opponents to become the last person standing. PLAYERUNKNOWN , aka Brendan Greene, is a pioneer of the battle royale genre and the creator of the battle royale game modes in the ARMA series and H1Z1: King of the Kill. At PUBG Corp., Greene is working with a veteran team of developers to make PUBG into the world's premiere battle royale experience."

# %%
df[(df["game_description"].isna())&(df["desc_snippet"].notna())]
# Out:
#        index                                                url   types  \
# 5          5  https://store.steampowered.com/bundle/5699/Gra...  bundle
# 15        15  https://store.steampowered.com/bundle/5641/Hea...  bundle
# 25        25  https://store.steampowered.com/bundle/234/Port...  bundle
# 39        39          https://store.steampowered.com/sub/18397/     sub
# 44        44  https://store.steampowered.com/bundle/2405/The...  bundle
# ...      ...                                                ...     ...
# 39363  39365  https://store.steampowered.com/bundle/8092/201...  bundle
# 39364  39366  https://store.steampowered.com/bundle/4380/Blu...  bundle
# 40233  40235         https://store.steampowered.com/sub/354233/     sub
# 40235  40237  https://store.steampowered.com/bundle/9680/Gro...  bundle
# 40236  40238         https://store.steampowered.com/sub/354231/     sub
#
#                                                 name  \
# 5         Grand Theft Auto V: Premium Online Edition
# 15              Hearts of Iron IV: Mobilization Pack
# 25                                     Portal Bundle
# 39                             Doom Classic Complete
# 44     The Binding of Isaac: Rebirth Complete Bundle
# ...                                              ...
# 39363                         2018 Yamaha UTV Bundle
# 39364  Blue Reflection - Vacation Style Complete Set
# 40233              Valve Index Headset + Controllers
# 40235            Groove Coaster - Touhou DLC Pack 04
# 40236                             Valve Index VR Kit
#
#                                             desc_snippet recent_reviews  \
# 5      Grand Theft Auto V: Premium Online Edition bundle            NaN
# 15           Hearts of Iron IV: Mobilization Pack bundle            NaN
# 25                                  Portal Bundle bundle            NaN
# 39                          Doom Classic Complete bundle            NaN
# 44     The Binding of Isaac: Rebirth Complete Bundle ...            NaN
# ...                                                  ...            ...
# 39363                      2018 Yamaha UTV Bundle bundle            NaN
# 39364  Blue Reflection - Vacation Style Complete Set ...            NaN
# 40233           Valve Index Headset + Controllers bundle            NaN
# 40235         Groove Coaster - Touhou DLC Pack 04 bundle            NaN
# 40236                          Valve Index VR Kit bundle            NaN
#
#       all_reviews release_date                   developer  \
# 5             NaN          NaN              Rockstar North
# 15            NaN          NaN  Paradox Development Studio
# 25            NaN          NaN                       Valve
# 39            NaN          NaN                 id Software
# 44            NaN          NaN               Nicalis, Inc.
# ...           ...          ...                         ...
# 39363         NaN          NaN             Rainbow Studios
# 39364         NaN          NaN  KOEI TECMO GAMES CO., LTD.
# 40233         NaN          NaN                         NaN
# 40235         NaN          NaN                 TAITO CORP.
# 40236         NaN          NaN                         NaN
#
#                         publisher  ...  \
# 5                  Rockstar Games  ...
# 15            Paradox Interactive  ...
# 25                          Valve  ...
# 39                    id Software  ...
# 44                  Nicalis, Inc.  ...
# ...                           ...  ...
# 39363                  THQ Nordic  ...
# 39364  KOEI TECMO GAMES CO., LTD.  ...
# 40233                         NaN  ...
# 40235                         NaN  ...
# 40236                         NaN  ...
#
#                                             game_details  \
# 5      Single-player,Multi-player,Downloadable Conten...
# 15     Single-player,Multi-player,Online Multi-Player...
# 25     Single-player,Co-op,Steam Achievements,Full co...
# 39                Single-player,Multi-player,Steam Cloud
# 44     Single-player,Multi-player,Local Multi-Player,...
# ...                                                  ...
# 39363  Single-player,Multi-player,Online Multi-Player...
# 39364  Single-player,Downloadable Content,Steam Achie...
# 40233                                                NaN
# 40235  Single-player,Downloadable Content,Steam Achie...
# 40236                                                NaN
#
#                                                languages achievements  \
# 5      English, French, Italian, German, Spanish - Sp...          NaN
# 15     English, French, German, Polish, Portuguese - ...          NaN
# 25     English, French, German, Russian, Danish, Dutc...          NaN
# 39                                               English          NaN
# 44                                               English          NaN
# ...                                                  ...          ...
# 39363  English, French, Italian, German, Spanish - Sp...          NaN
# 39364             English, Japanese, Traditional Chinese          NaN
# 40233                                                NaN          NaN
# 40235                                  English, Japanese          NaN
# 40236                                                NaN          NaN
#
#                           genre game_description mature_content  \
# 5              Action,Adventure              NaN            NaN
# 15          Simulation,Strategy              NaN            NaN
# 25             Action,Adventure              NaN            NaN
# 39                       Action              NaN            NaN
# 44       Action,Adventure,Indie              NaN            NaN
# ...                         ...              ...            ...
# 39363  Racing,Simulation,Sports              NaN            NaN
# 39364                       RPG              NaN            NaN
# 40233                       NaN              NaN            NaN
# 40235                    Action              NaN            NaN
# 40236                       NaN              NaN            NaN
#
#       minimum_requirements recommended_requirements original_price  \
# 5                      NaN                      NaN            NaN
# 15                     NaN                      NaN            NaN
# 25                     NaN                      NaN            NaN
# 39                     NaN                      NaN         $14.99
# 44                     NaN                      NaN            NaN
# ...                    ...                      ...            ...
# 39363                  NaN                      NaN            NaN
# 39364                  NaN                      NaN            NaN
# 40233                  NaN                      NaN        $749.00
# 40235                  NaN                      NaN            NaN
# 40236                  NaN                      NaN        $999.00
#
#       discount_price
# 5             $35.18
# 15            $94.45
# 25            $14.98
# 39             $7.49
# 44            $35.97
# ...              ...
# 39363          $6.08
# 39364         $23.95
# 40233            NaN
# 40235          $6.36
# 40236            NaN
#
# [2812 rows x 21 columns]

# %%
df[(df["game_description"].notna())&(df["desc_snippet"].isna())]
# Out:
#        index                                                url types  \
# 826      827  https://store.steampowered.com/app/441340/Elit...   app
# 1771    1772  https://store.steampowered.com/app/57600/Tropi...   app
# 2104    2105  https://store.steampowered.com/app/9070/DOOM_3...   app
# 2375    2376  https://store.steampowered.com/app/201310/X3_A...   app
# 3477    3478  https://store.steampowered.com/app/8650/RACE_0...   app
# ...      ...                                                ...   ...
# 40825  40827  https://store.steampowered.com/app/899835/Rock...   app
# 40826  40828  https://store.steampowered.com/app/899836/Rock...   app
# 40827  40829  https://store.steampowered.com/app/899832/Rock...   app
# 40828  40830  https://store.steampowered.com/app/906840/Fant...   app
# 40829  40831  https://store.steampowered.com/app/906635/Mega...   app
#
#                                                     name desc_snippet  \
# 826                Elite Dangerous: Horizons Season Pass          NaN
# 1771                           Tropico 3: Absolute Power          NaN
# 2104                         DOOM 3 Resurrection of Evil          NaN
# 2375                                  X3: Albion Prelude          NaN
# 3477   RACE 07: Andy Priaulx Crowne Plaza Raceway (Fr...          NaN
# ...                                                  ...          ...
# 40825  Rocksmith® 2014 Edition – Remastered – Sabaton...          NaN
# 40826  Rocksmith® 2014 Edition – Remastered – Sabaton...          NaN
# 40827  Rocksmith® 2014 Edition – Remastered – Stone T...          NaN
# 40828  Fantasy Grounds - Quests of Doom 4: A Midnight...          NaN
# 40829                       Mega Man X5 Sound Collection          NaN
#
#                                           recent_reviews  \
# 826    Mixed,(21),- 42% of the 21 user reviews in the...
# 1771                                                 NaN
# 2104                                                 NaN
# 2375                                                 NaN
# 3477                                                 NaN
# ...                                                  ...
# 40825                                                NaN
# 40826                                                NaN
# 40827                                                NaN
# 40828                                                NaN
# 40829                                                NaN
#
#                                              all_reviews  release_date  \
# 826    Mostly Positive,(1,082),- 76% of the 1,082 use...  Dec 15, 2015
# 1771   Very Positive,(223),- 94% of the 223 user revi...  May 17, 2010
# 2104   Very Positive,(338),- 84% of the 338 user revi...   Apr 3, 2005
# 2375   Very Positive,(1,042),- 92% of the 1,042 user ...  Dec 15, 2011
# 3477   Mixed,(56),- 62% of the 56 user reviews for th...  Jun 19, 2008
# ...                                                  ...           ...
# 40825                                                NaN  Feb 12, 2019
# 40826                                                NaN  Feb 12, 2019
# 40827                                                NaN   Feb 5, 2019
# 40828                                                NaN  Jul 31, 2018
# 40829                                                NaN  Jul 24, 2018
#
#                      developer                                    publisher  \
# 826      Frontier Developments  Frontier Developments,Frontier Developments
# 1771           Haemimont Games  Kalypso Media Digital,Kalypso Media Digital
# 2104               id Software                      id Software,id Software
# 2375                   Egosoft                              Egosoft,Egosoft
# 3477                    SimBin                                SimBin,SimBin
# ...                        ...                                          ...
# 40825  Ubisoft - San Francisco                                          NaN
# 40826  Ubisoft - San Francisco                                          NaN
# 40827  Ubisoft - San Francisco                                          NaN
# 40828      SmiteWorks USA, LLC                                          NaN
# 40829          CAPCOM CO., LTD              CAPCOM CO., LTD,CAPCOM CO., LTD
#
#        ...                                       game_details  \
# 826    ...  Single-player,Multi-player,MMO,Co-op,Downloada...
# 1771   ...                 Single-player,Downloadable Content
# 2104   ...  Single-player,Multi-player,Downloadable Conten...
# 2375   ...  Single-player,Downloadable Content,Steam Achie...
# 3477   ...                               Downloadable Content
# ...    ...                                                ...
# 40825  ...  Single-player,Shared/Split Screen,Downloadable...
# 40826  ...  Single-player,Shared/Split Screen,Downloadable...
# 40827  ...  Single-player,Shared/Split Screen,Downloadable...
# 40828  ...  Multi-player,Co-op,Cross-Platform Multiplayer,...
# 40829  ...  Single-player,Downloadable Content,Steam Achie...
#
#                                                languages achievements  \
# 826        English,French,German,Russian,Spanish - Spain          NaN
# 1771       English,French,German,Italian,Spanish - Spain          NaN
# 2104                                             English          NaN
# 2375   English,French,German,Italian,Russian,Polish,S...         33.0
# 3477       English,French,German,Italian,Spanish - Spain          NaN
# ...                                                  ...          ...
# 40825  English,German,French,Italian,Spanish - Spain,...          NaN
# 40826  English,German,French,Italian,Spanish - Spain,...          NaN
# 40827  English,German,French,Italian,Spanish - Spain,...          NaN
# 40828                                            English          NaN
# 40829  English,French,Italian,German,Spanish - Spain,...          NaN
#
#                                                    genre  \
# 826    Action,Adventure,Massively Multiplayer,RPG,Sim...
# 1771                                 Simulation,Strategy
# 2104                                              Action
# 2375                                   Action,Simulation
# 3477                                              Racing
# ...                                                  ...
# 40825                                  Casual,Simulation
# 40826                                  Casual,Simulation
# 40827                                  Casual,Simulation
# 40828                                 Indie,RPG,Strategy
# 40829                                             Action
#
#                                         game_description mature_content  \
# 826     About This Content Change the galaxy with the...            NaN
# 1771    About This Content  Tropico 3: Absolute Power...            NaN
# 2104    About This Content  The gripping expansion pa...            NaN
# 2375    About This Content X3: Albion Prelude is the ...            NaN
# 3477    About This Content Blue skies and white beach...            NaN
# ...                                                  ...            ...
# 40825   About This Content Play "Primo Victoria" by S...            NaN
# 40826   About This Content Play "Ghost Division" by S...            NaN
# 40827   About This Content Play "Trippin’ on a Hole i...            NaN
# 40828   About This Content  Quests of Doom 4: A Midni...            NaN
# 40829   About This Content Get equipped with the stun...            NaN
#
#                                     minimum_requirements  \
# 826    Minimum:,OS:,Windows 7/8/10 64-bit,Processor:,...
# 1771                                                 NaN
# 2104                                                 NaN
# 2375   Minimum:,OS:,Windows 10 / 8 / 7 / Vista SP1 / ...
# 3477                                                 NaN
# ...                                                  ...
# 40825  Minimum:,OS:,Windows Vista, Windows 7, Windows...
# 40826  Minimum:,OS:,Windows Vista, Windows 7, Windows...
# 40827  Minimum:,OS:,Windows Vista, Windows 7, Windows...
# 40828  Minimum:,OS:,Windows 7x , 8x or 10x,Processor:...
# 40829  Minimum:,OS:,WINDOWS® 7 (64bit),Processor:,Int...
#
#                                 recommended_requirements original_price  \
# 826    Recommended:,OS:,Windows 7/8/10 64-bit,Process...         $29.99
# 1771                                                 NaN          $9.99
# 2104                                                 NaN          $2.99
# 2375   Recommended:,OS:,Windows 10 / 8 / 7 / Vista SP...          $9.99
# 3477                                                 NaN         $39.99
# ...                                                  ...            ...
# 40825  Recommended:,OS:,Windows Vista, Windows 7, Win...          $2.99
# 40826  Recommended:,OS:,Windows Vista, Windows 7, Win...          $2.99
# 40827  Recommended:,OS:,Windows Vista, Windows 7, Win...          $2.99
# 40828  Recommended:,OS:,Windows 7x , 8x or 10x,Proces...          $7.99
# 40829  Recommended:,OS:,WINDOWS®10 (64bit),Processor:...          $9.99
#
#       discount_price
# 826          $320.94
# 1771         $115.97
# 2104           $1.79
# 2375             NaN
# 3477             NaN
# ...              ...
# 40825            NaN
# 40826            NaN
# 40827            NaN
# 40828            NaN
# 40829            NaN
#
# [13120 rows x 21 columns]

# %% [markdown]
# Columns `desc_snippet` and `game_description` has the same meaning, but I prefer `game_description` because this column has more data (words to be said) than `desc_snippet`. So I take `game_description` data, and if it is null, it will be replaced with `desc_snippet`

# %%
description_game = []
for i in range(len(df)):
    if df["game_description"][i] is not None:
        description_game.append(df["game_description"][i])
    elif (df["game_description"] is None)&(df["desc_snippet"]is not None):
        description_game.append(df["desc_snippet"][i])
    else:
        description_game.append("")

# %%
df["description_game"] = description_game
df["description_game"] = df["description_game"].fillna("")

# %% [markdown]
# Next, I clean up the description. There are sentences that were repeated in almost every games, these are "About This Game" and "About This Content". Also, I want the description no longer contain stopwords such as "and", "or", etc.

# %%
def text_format(text):
    '''
    Formatting input: change to lemma form, remove stopwords, special char, and etc.
    '''
    # lemmatization
    lemmatizer = WordNetLemmatizer()
    lemmatizer.lemmatize(text)
    text_lemmatized = [lemmatizer.lemmatize(word) for word in text.split()]
    text = " ".join(text_lemmatized)
        
    # filter from stopwords
    stop_words = set(stopwords.words('english'))
    filtered_from_stopwords = [word for word in text.split() if not word in stop_words]
        
    text = " ".join(filtered_from_stopwords)
    text = re.sub("About This Game","",text)
    text = re.sub("About This Content","",text)
        
    return text

# %%
desc_clean = []
for index, row in df[['description_game']].iterrows():
    # formatting text
    outputs = text_format(row[0])
    desc_clean.append(outputs)

# %%
df["description_clean"]=desc_clean

# %% [markdown]
# ## Reviews

# %% [markdown]
# I used `all_reviews` column to evaluate the review of the game. About the rating, I will use the predicate that steam used, such as Very Positive, Mostly Positive, etc. I got dictionary about rating predicate in steam in this discussion: https://steamcommunity.com/discussions/forum/0/1744483505466407549/

# %% [markdown]
# Then, I used that dictionary to be used in `all_reviews` predicate:
# - Overhwelmingly Positive = 9
# - Very Positive = 8
# - Positive = 7
# - Mostly Positive = 6
# - Mixed = 5
# - Mostly Negative = 4
# - Negative = 3
# - Very Negative = 2
# - Overwhelmingly Negative = 1

# %% [markdown]
# The problem about this feature is the information about rating predicate and reviewers number of a games contained in a column. So I need to extract these two informations.

# %% [markdown]
# **Extracting Review Predicate**

# %%
df[['all_reviews']]
# Out:
#                                              all_reviews
# 0      Very Positive,(42,550),- 92% of the 42,550 use...
# 1      Mixed,(836,608),- 49% of the 836,608 user revi...
# 2      Mostly Positive,(7,030),- 71% of the 7,030 use...
# 3      Mixed,(167,115),- 61% of the 167,115 user revi...
# 4      Mostly Positive,(11,481),- 74% of the 11,481 u...
# ...                                                  ...
# 40826                                                NaN
# 40827                                                NaN
# 40828                                                NaN
# 40829                                                NaN
# 40830                                                NaN
#
# [40831 rows x 1 columns]

# %% [markdown]
# Notice that every rating predicate is located in the first sentence/word before the first comma. I used split function to separate this element in the list.

# %%
df['all_reviews'] = df['all_reviews'].fillna("")
df['review_list'] = df['all_reviews'].str.split(',')

# %% [markdown]
# After I split the `all_reviews` column, this column will contain list of information about reviews separated by ",".
# Now, I just need to get the first element from the list in every row, and I will get the rating predicate.

# %%
review_rate_str = []
for i in range(len(df)):
    review_rate_str.append(df['review_list'][i][0])

# %%
review_rate_str
# Out:
# ['Very Positive',
#  'Mixed',
#  'Mostly Positive',
#  'Mixed',
#  'Mostly Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mixed',
#  'Mostly Positive',
#  '',
#  'Very Positive',
#  'Mostly Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mixed',
#  '',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  '',
#  '7 user reviews',
#  'Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  '',
#  'Overwhelmingly Positive',
#  '',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  '',
#  'Very Positive',
#  'Mixed',
#  '',
#  'Mixed',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Overwhelmingly Positive',
#  '',
#  'Mixed',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  '',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  '',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mixed',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Mostly Positive',
#  '',
#  '',
#  'Mostly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mixed',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mixed',
#  'Mostly Positive',
#  '',
#  'Very Positive',
#  '',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Mixed',
#  'Overwhelmingly Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  '',
#  'Mostly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  '1 user reviews',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mixed',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  '',
#  'Mostly Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Mixed',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Mostly Positive',
#  '',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  '',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  '',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  '',
#  'Mostly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Mixed',
#  'Very Positive',
#  '',
#  'Mixed',
#  '',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mixed',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  '',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Mixed',
#  '',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  '',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  '',
#  'Mostly Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  '',
#  'Mostly Positive',
#  'Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Mixed',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mostly Negative',
#  'Mixed',
#  'Overwhelmingly Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mixed',
#  'Mostly Positive',
#  'Very Positive',
#  '',
#  'Mixed',
#  '',
#  'Mixed',
#  'Mostly Positive',
#  'Mostly Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Mostly Positive',
#  'Mixed',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Overwhelmingly Positive',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mixed',
#  '',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  '',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mixed',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  'Mixed',
#  '',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Mostly Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  '',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Mostly Negative',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  '',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Mixed',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mixed',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mixed',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Mixed',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  '',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  '',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Mostly Positive',
#  'Mixed',
#  'Mixed',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mixed',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  '',
#  'Mostly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  '',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Mostly Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  '',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mixed',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  'Mixed',
#  'Overwhelmingly Positive',
#  'Mixed',
#  'Very Positive',
#  '',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  '',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mixed',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Mixed',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  '',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  '',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mixed',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mixed',
#  'Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mixed',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  '',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Mixed',
#  'Mixed',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  '',
#  'Mixed',
#  'Mostly Positive',
#  'Very Positive',
#  'Mixed',
#  'Mostly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Mixed',
#  '',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  '',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  '',
#  'Overwhelmingly Positive',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  'Mixed',
#  '',
#  'Very Positive',
#  '',
#  'Mostly Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  '',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Mostly Positive',
#  'Very Positive',
#  '',
#  'Mixed',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Mixed',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  '7 user reviews',
#  'Mostly Positive',
#  '',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Mostly Positive',
#  'Mixed',
#  'Mostly Positive',
#  '',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  '',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  '',
#  '',
#  'Mostly Positive',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Mixed',
#  'Very Positive',
#  'Overwhelmingly Positive',
#  'Overwhelmingly Positive',
#  'Very Positive',
#  'Mixed',
#  '5 user reviews',
#  '',
#  'Very Positive',
#  'Mostly Positive',
#  'Very Positive',
#  'Positive',
#  '7 user reviews',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Very Positive',
#  'Positive',
#  'Very Positive',
#  'Mostly Positive',
#  '',
#  'Overwhelmingly Positive',
#  'Mostly Positive',
#  'Very Positive',
#  ...]

# %%
df["predicate_rating"] = review_rate_str

# %% [markdown]
# Next, I transform this predicate to integer rate according to the dictionary I used.

# %%
rating_int=[]
for i in range(len(df)):
    if df["predicate_rating"][i] == 'Overhwelmingly Positive':
        rating_int.append(9)
    elif df["predicate_rating"][i] == 'Very Positive':
        rating_int.append(8)
    elif df["predicate_rating"][i] == 'Positive':
        rating_int.append(7)
    elif df["predicate_rating"][i] == 'Mostly Positive':
        rating_int.append(6)
    elif df["predicate_rating"][i] == 'Mixed':
        rating_int.append(5)
    elif df["predicate_rating"][i] == 'Mostly Negative':
        rating_int.append(4)
    elif df["predicate_rating"][i] == 'Negative':
        rating_int.append(3)
    elif df["predicate_rating"][i] == 'Very Negative':
        rating_int.append(2)
    elif df["predicate_rating"][i] == 'Overhwelmingly Negative':
        rating_int.append(1)
    else:
        rating_int.append(0)

# %%
df["rating_int"] = rating_int

# %% [markdown]
# **Extracting Number of Reviewers**

# %%
df[['all_reviews']]
# Out:
#                                              all_reviews
# 0      Very Positive,(42,550),- 92% of the 42,550 use...
# 1      Mixed,(836,608),- 49% of the 836,608 user revi...
# 2      Mostly Positive,(7,030),- 71% of the 7,030 use...
# 3      Mixed,(167,115),- 61% of the 167,115 user revi...
# 4      Mostly Positive,(11,481),- 74% of the 11,481 u...
# ...                                                  ...
# 40826
# 40827
# 40828
# 40829
# 40830
#
# [40831 rows x 1 columns]

# %% [markdown]
# Every reviewer number is stored in a parentheses bracket. I just need to detect the value in this parentheses.

# %%
df["reviewers_number"] = df["all_reviews"].str.replace(r'[^(]*\(|\)[^)]*', '')
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
df["reviewers_number"].tolist()
# Out:
# ['42,550',
#  '836,608',
#  '7,030',
#  '167,115',
#  '11,481',
#  '',
#  '9,645',
#  '23,763',
#  '12,127',
#  '904',
#  '4,600',
#  '3,547',
#  '14,184',
#  '1,118',
#  '5,484',
#  '',
#  '1,901',
#  '1,945',
#  '1,797',
#  '2,442',
#  '4,190',
#  '382',
#  '487',
#  '9,757',
#  '43,799',
#  '',
#  '40,424',
#  '5,414',
#  '1,094',
#  '2,701',
#  '15,461',
#  '21,022',
#  '4,612',
#  '8,128',
#  '5,252',
#  '27,397',
#  '805',
#  '4,437',
#  '8,950',
#  '',
#  '7 user reviews,- Need more user reviews to generate a score',
#  '11',
#  '45,829',
#  '7,855',
#  '',
#  '7,779',
#  '5,997',
#  '2,396',
#  '9,007',
#  '417',
#  '88',
#  '1,731',
#  '5,090',
#  '28,082',
#  '16,973',
#  '1,786',
#  '8,597',
#  '',
#  '561',
#  '',
#  '8,015',
#  '5,694',
#  '7,557',
#  '',
#  '12,784',
#  '27,708',
#  '',
#  '16,225',
#  '',
#  '7,674',
#  '479',
#  '6,100',
#  '4,030',
#  '37,698',
#  '',
#  '12,703',
#  '6,311',
#  '4,809',
#  '15,680',
#  '35',
#  '14,138',
#  '',
#  '37,858',
#  '59,252',
#  '10,495',
#  '2,454',
#  '',
#  '2,677',
#  '51',
#  '54,938',
#  '',
#  '27,036',
#  '12,948',
#  '3,348',
#  '7,238',
#  '101,309',
#  '3,511',
#  '3,286',
#  '8,966',
#  '381',
#  '9,192',
#  '22,352',
#  '',
#  '5,507',
#  '7,712',
#  '',
#  '',
#  '4,586',
#  '2,720',
#  '8,097',
#  '6,807',
#  '5,939',
#  '3,174',
#  '4,915',
#  '',
#  '1,589',
#  '245',
#  '10,687',
#  '9,773',
#  '',
#  '340',
#  '1,196',
#  '644',
#  '47,716',
#  '33,278',
#  '3,858',
#  '12,121',
#  '897',
#  '10,683',
#  '1,147',
#  '16,220',
#  '2,684',
#  '11,602',
#  '',
#  '28,180',
#  '',
#  '2,033',
#  '2,335',
#  '862',
#  '3,452',
#  '24,439',
#  '3,970',
#  '7,088',
#  '278',
#  '3,686',
#  '',
#  '7,942',
#  '5,255',
#  '1,656',
#  '11,168',
#  '9,328',
#  '1,568',
#  '1 user reviews,- Need more user reviews to generate a score',
#  '22,177',
#  '617',
#  '823',
#  '24,747',
#  '13,158',
#  '2,827',
#  '1,546',
#  '9,220',
#  '13,457',
#  '35,412',
#  '',
#  '11,784',
#  '27,873',
#  '44,454',
#  '4,582',
#  '4,179',
#  '',
#  '4,786',
#  '137',
#  '',
#  '4,292',
#  '364',
#  '31,338',
#  '1,571',
#  '3,738',
#  '10,033',
#  '363',
#  '',
#  '3,181',
#  '8,410',
#  '9,096',
#  '87,700',
#  '5,271',
#  '3,746',
#  '',
#  '10,938',
#  '132,814',
#  '7,583',
#  '',
#  '',
#  '23,264',
#  '725',
#  '184',
#  '401',
#  '31,375',
#  '14,923',
#  '',
#  '62,025',
#  '10,245',
#  '2,407',
#  '24,391',
#  '',
#  '3,248',
#  '9,138',
#  '2,566',
#  '12,902',
#  '4,598',
#  '102',
#  '',
#  '9,340',
#  '',
#  '2,124',
#  '17,438',
#  '',
#  '46,412',
#  '291',
#  '21,366',
#  '5,387',
#  '703',
#  '59,100',
#  '20,835',
#  '15,667',
#  '1,686',
#  '3,692',
#  '49,909',
#  '679',
#  '620',
#  '',
#  '',
#  '12,384',
#  '14,567',
#  '24,131',
#  '63,149',
#  '4,174',
#  '',
#  '13,207',
#  '252',
#  '956',
#  '',
#  '3,526',
#  '1,521',
#  '',
#  '9,782',
#  '30,161',
#  '37,382',
#  '7,419',
#  '5,361',
#  '',
#  '23,516',
#  '28,383',
#  '28,359',
#  '3,494',
#  '104,354',
#  '17,415',
#  '13,041',
#  '13,523',
#  '',
#  '6,779',
#  '28',
#  '3,375',
#  '710',
#  '',
#  '4,745',
#  '21,539',
#  '22,009',
#  '11,388',
#  '32,562',
#  '3,435',
#  '156,890',
#  '10,993',
#  '4,028',
#  '42,821',
#  '5,844',
#  '9,124',
#  '2,100',
#  '2,029',
#  '10,227',
#  '14,492',
#  '4,357',
#  '20,699',
#  '19,157',
#  '',
#  '12,778',
#  '87,871',
#  '63,223',
#  '24,456',
#  '4,663',
#  '55,096',
#  '2,475',
#  '52,056',
#  '4,344',
#  '20,858',
#  '4,490',
#  '2,526',
#  '36,134',
#  '35,536',
#  '35,444',
#  '2,704',
#  '2,617',
#  '1,274',
#  '57,157',
#  '7,877',
#  '5,388',
#  '11,925',
#  '25,172',
#  '215,078',
#  '23,376',
#  '15,963',
#  '9,320',
#  '102,974',
#  '3,385',
#  '17,470',
#  '11,786',
#  '8,785',
#  '3,399',
#  '2,922',
#  '',
#  '204,137',
#  '441',
#  '474',
#  '51,814',
#  '155',
#  '83,973',
#  '6,709',
#  '46,206',
#  '1,746',
#  '15,083',
#  '',
#  '13,413',
#  '38,652',
#  '23,366',
#  '13,069',
#  '310,394',
#  '90,153',
#  '2,137',
#  '728',
#  '14,265',
#  '358',
#  '28,513',
#  '6,474',
#  '70,020',
#  '21,046',
#  '24,605',
#  '571',
#  '4,787',
#  '',
#  '23,982',
#  '',
#  '9,311',
#  '27,512',
#  '10,144',
#  '',
#  '101,595',
#  '20,758',
#  '4,669',
#  '14,274',
#  '',
#  '22,740',
#  '6,842',
#  '21,514',
#  '201,266',
#  '1,174',
#  '44,559',
#  '',
#  '30,585',
#  '21,600',
#  '3,416',
#  '44,074',
#  '31,754',
#  '104,530',
#  '168,982',
#  '20,901',
#  '22,330',
#  '447',
#  '81,705',
#  '62,030',
#  '',
#  '18,794',
#  '699',
#  '',
#  '',
#  '41,391',
#  '16,312',
#  '553,458',
#  '8,863',
#  '389',
#  '12,027',
#  '107,537',
#  '138,492',
#  '61,962',
#  '13,436',
#  '8,984',
#  '55,276',
#  '33,954',
#  '21,177',
#  '38,130',
#  '10,266',
#  '15,312',
#  '1,375',
#  '14,413',
#  '',
#  '14,443',
#  '90,387',
#  '206,811',
#  '407,706',
#  '250,319',
#  '18,127',
#  '189,538',
#  '13,902',
#  '188,275',
#  '10,916',
#  '95,522',
#  '72,726',
#  '248,689',
#  '',
#  '78,960',
#  '1,015,621',
#  '',
#  '36,796',
#  '3,094,223',
#  '',
#  '9,128',
#  '',
#  '1,844',
#  '13,376',
#  '43,174',
#  '13,771',
#  '1,032',
#  '1,581',
#  '5,017',
#  '19,362',
#  '2,898',
#  '2,674',
#  '181',
#  '8,049',
#  '17,445',
#  '1,410',
#  '178',
#  '192',
#  '315',
#  '3,340',
#  '667',
#  '1,210',
#  '16',
#  '1,801',
#  '8,132',
#  '',
#  '1,024',
#  '575',
#  '272',
#  '1,250',
#  '1,570',
#  '7,084',
#  '246',
#  '7,444',
#  '8,216',
#  '21,159',
#  '3,595',
#  '57,275',
#  '13,220',
#  '30,189',
#  '2,346',
#  '2,793',
#  '',
#  '45,685',
#  '513',
#  '69',
#  '10,665',
#  '446',
#  '374',
#  '72,114',
#  '381',
#  '2,023',
#  '1,845',
#  '50',
#  '1,099',
#  '391',
#  '3,854',
#  '950',
#  '1,094',
#  '444',
#  '80',
#  '176',
#  '',
#  '383',
#  '715',
#  '34',
#  '6,933',
#  '8,825',
#  '331',
#  '368',
#  '19',
#  '5,916',
#  '1,491',
#  '31,966',
#  '3,915',
#  '3,141',
#  '115',
#  '',
#  '21,671',
#  '137',
#  '4,488',
#  '4,056',
#  '',
#  '4,708',
#  '3,696',
#  '360',
#  '6,555',
#  '7,518',
#  '2,365',
#  '2,867',
#  '389',
#  '7,958',
#  '7,964',
#  '585',
#  '6,288',
#  '759',
#  '10,571',
#  '10,520',
#  '5,348',
#  '13,288',
#  '535',
#  '30,216',
#  '17,680',
#  '1,898',
#  '34,978',
#  '',
#  '3,897',
#  '17,932',
#  '',
#  '2,971',
#  '278',
#  '792',
#  '273',
#  '3,383',
#  '834',
#  '',
#  '6,596',
#  '7,014',
#  '',
#  '24,840',
#  '6,256',
#  '925',
#  '',
#  '18,993',
#  '300',
#  '27,039',
#  '1,541',
#  '131',
#  '310',
#  '110',
#  '38,431',
#  '6,163',
#  '325',
#  '1,458',
#  '643',
#  '',
#  '3,690',
#  '',
#  '3,371',
#  '6,356',
#  '7,758',
#  '1,225',
#  '1,465',
#  '14,678',
#  '',
#  '',
#  '3,782',
#  '6,511',
#  '416',
#  '2,351',
#  '147',
#  '279',
#  '3,358',
#  '5,680',
#  '937',
#  '2,659',
#  '3,966',
#  '346',
#  '48',
#  '442',
#  '20,450',
#  '1,967',
#  '38,402',
#  '7,154',
#  '1,315',
#  '42,445',
#  '1,171',
#  '49,284',
#  '1,392',
#  '51,065',
#  '1,160',
#  '',
#  '22,515',
#  '6,306',
#  '328',
#  '1,738',
#  '350',
#  '3,145',
#  '',
#  '2,126',
#  '35,642',
#  '10,120',
#  '4,976',
#  '3,649',
#  '357',
#  '1,602',
#  '',
#  '1,359',
#  '13,668',
#  '102',
#  '6,572',
#  '69',
#  '1,405',
#  '1,751',
#  '3,776',
#  '5,929',
#  '327',
#  '2,417',
#  '7,017',
#  '5,461',
#  '9,233',
#  '11,267',
#  '27,014',
#  '3,344',
#  '1,621',
#  '341',
#  '14,072',
#  '3,209',
#  '2,990',
#  '',
#  '132',
#  '943',
#  '42,245',
#  '3,754',
#  '1,025',
#  '6,314',
#  '4,097',
#  '51,251',
#  '2,598',
#  '1,528',
#  '',
#  '',
#  '1,124',
#  '644',
#  '501',
#  '25,279',
#  '1,392',
#  '4,667',
#  '4,712',
#  '2,075',
#  '2,896',
#  '1,844',
#  '508',
#  '13,777',
#  '1,605',
#  '924',
#  '11,052',
#  '325,675',
#  '5,089',
#  '45',
#  '624',
#  '2,201',
#  '10,911',
#  '571',
#  '449',
#  '9,709',
#  '928',
#  '16,656',
#  '15,835',
#  '1,666',
#  '1,914',
#  '4,624',
#  '6,254',
#  '15,658',
#  '',
#  '2,296',
#  '22,219',
#  '499',
#  '1,009',
#  '970',
#  '',
#  '397',
#  '1,672',
#  '538',
#  '2,751',
#  '3,738',
#  '39,418',
#  '4,806',
#  '',
#  '1,589',
#  '13,369',
#  '1,520',
#  '7,934',
#  '2,845',
#  '',
#  '341',
#  '1,639',
#  '5,157',
#  '19,672',
#  '12,305',
#  '2,123',
#  '',
#  '605',
#  '4,158',
#  '79',
#  '12,849',
#  '8,768',
#  '30,568',
#  '',
#  '1,675',
#  '715',
#  '13,605',
#  '25,634',
#  '7,713',
#  '',
#  '766',
#  '',
#  '1,134',
#  '5,181',
#  '1,187',
#  '3,626',
#  '2,896',
#  '2,224',
#  '11,454',
#  '2,318',
#  '762',
#  '519',
#  '1,798',
#  '19,641',
#  '4,657',
#  '3,697',
#  '17,561',
#  '33,808',
#  '1,131',
#  '18',
#  '1,667',
#  '255',
#  '446',
#  '253',
#  '35,947',
#  '15,270',
#  '8,061',
#  '1,670',
#  '12,138',
#  '7,011',
#  '4,487',
#  '23,931',
#  '3,777',
#  '6,984',
#  '629',
#  '',
#  '7,753',
#  '3,396',
#  '14,947',
#  '2,030',
#  '5,198',
#  '6,426',
#  '23,394',
#  '2,407',
#  '23,961',
#  '5,075',
#  '24,003',
#  '',
#  '2,817',
#  '',
#  '608',
#  '3,406',
#  '107',
#  '',
#  '2,598',
#  '432',
#  '4,624',
#  '4,813',
#  '18,350',
#  '4,675',
#  '4,516',
#  '1,585',
#  '30,195',
#  '406',
#  '',
#  '1,354',
#  '15,266',
#  '1,058',
#  '1,073',
#  '9,806',
#  '1,197',
#  '4,298',
#  '6,093',
#  '233',
#  '67',
#  '1,998',
#  '3,191',
#  '6,492',
#  '14,373',
#  '715',
#  '2,357',
#  '123,683',
#  '4,272',
#  '3,035',
#  '1,995',
#  '25,473',
#  '6,085',
#  '',
#  '45,188',
#  '1,207',
#  '',
#  '13,811',
#  '843',
#  '',
#  '4,993',
#  '7,504',
#  '19,094',
#  '37,769',
#  '466',
#  '',
#  '21,657',
#  '5,738',
#  '624',
#  '',
#  '2,445',
#  '3,818',
#  '98',
#  '1,082',
#  '71',
#  '',
#  '10,184',
#  '',
#  '2,741',
#  '25,242',
#  '10,838',
#  '8,260',
#  '4,412',
#  '17,673',
#  '533',
#  '3,109',
#  '1,686',
#  '1,775',
#  '5,546',
#  '2,898',
#  '23,579',
#  '3,668',
#  '14,690',
#  '2,315',
#  '',
#  '707',
#  '',
#  '1,494',
#  '2,688',
#  '',
#  '1,156',
#  '',
#  '25,748',
#  '1,985',
#  '2,696',
#  '89',
#  '3,789',
#  '891',
#  '',
#  '20,861',
#  '1,318',
#  '6,506',
#  '1,108',
#  '922',
#  '2,374',
#  '488',
#  '2,988',
#  '3,167',
#  '',
#  '183',
#  '',
#  '8,074',
#  '106',
#  '12,361',
#  '2,747',
#  '1,222',
#  '79',
#  '287',
#  '363',
#  '3,739',
#  '1,024',
#  '15,046',
#  '377',
#  '60',
#  '5,100',
#  '8,597',
#  '2,184',
#  '267',
#  '',
#  '2,262',
#  '8,098',
#  '9,167',
#  '7,117',
#  '1,169',
#  '539',
#  '',
#  '1,447',
#  '2,031',
#  '72',
#  '331',
#  '172',
#  '419',
#  '780',
#  '4,914',
#  '7 user reviews,- Need more user reviews to generate a score',
#  '5,253',
#  '',
#  '2,270',
#  '773',
#  '1,078',
#  '54',
#  '2,144',
#  '1,052',
#  '2,164',
#  '208',
#  '264',
#  '33',
#  '',
#  '31,696',
#  '780',
#  '2,278',
#  '681',
#  '2,713',
#  '12,428',
#  '',
#  '8,506',
#  '309',
#  '2,938',
#  '7,434',
#  '12,000',
#  '4,404',
#  '393',
#  '1,089',
#  '109',
#  '382',
#  '8,870',
#  '10,491',
#  '1,643',
#  '4,285',
#  '20,986',
#  '572',
#  '7,243',
#  '5,278',
#  '1,967',
#  '1,073',
#  '26',
#  '140',
#  '4,383',
#  '',
#  '',
#  '79',
#  '775',
#  '33,405',
#  '4,764',
#  '1,299',
#  '4,276',
#  '498',
#  '305',
#  '355',
#  '1,178',
#  '1,288',
#  '24',
#  '90',
#  '1,238',
#  '204',
#  '539',
#  '4,281',
#  '3,557',
#  '1,244',
#  '543',
#  '358',
#  '1,227',
#  '1,458',
#  '2,001',
#  '1,597',
#  '4,786',
#  '703',
#  '5 user reviews,- Need more user reviews to generate a score',
#  '',
#  '931',
#  '437',
#  '23,036',
#  '11',
#  '7 user reviews,- Need more user reviews to generate a score',
#  '171',
#  '4,781',
#  '7,913',
#  '14,888',
#  '7,116',
#  '102',
#  '36',
#  '2,598',
#  '3,809',
#  '',
#  '1,244',
#  '841',
#  '1,541',
#  ...]

# %% [markdown]
# Need to delete the game that not qualify enough to be predicated (too few reviews), the value such as '7 user reviews,- Need more user reviews to generate a score', '1 user reviews,- Need more user reviews to generate a score', etc.

# %%
df.loc[df['reviewers_number'].str.contains('user'), 'reviewers_number'] = ''

# %%
#replace comma with blank so that I can convert it to integer
df["reviewers_number"] = df["reviewers_number"].str.replace(',', '')

# %%
#replace blank reviewer or null data to 0
for i in range(len(df)):
    if df["reviewers_number"][i] == '':
        df["reviewers_number"][i] = 0
    else:
        df["reviewers_number"][i] = df["reviewers_number"][i]
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ASUS\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#convert the reviewer number data to integer
df["reviewers_number"] = df["reviewers_number"].astype(dtype='int64')

# %%
df["reviewers_number"]
# Out:
# 0         42550
# 1        836608
# 2          7030
# 3        167115
# 4         11481
#           ...
# 40826         0
# 40827         0
# 40828         0
# 40829         0
# 40830         0
# Name: reviewers_number, Length: 40831, dtype: int64

# %% [markdown]
# Then, I used a formula from IMDb to weight the reviews based on how many reviewers in a game.
# Source: https://math.stackexchange.com/questions/169032/understanding-the-imdb-weighted-rating-function-for-usage-on-my-own-website

# %%
C = df['rating_int'].mean()

# %%
# Function that computes the weighted rating of each games
def weighted_rating(x=df, m=10, C=C):
    v = x['reviewers_number']
    R = x['rating_int']
    # Calculation based on the formula
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
df['weighted_rating'] = df.apply(weighted_rating, axis=1)

# %%
df[['rating_int','reviewers_number','weighted_rating']].head(5)
# Out:
#    rating_int  reviewers_number  weighted_rating
# 0           8             42550         7.998742
# 1           5            836608         4.999972
# 2           6              7030         5.995236
# 3           5            167115         4.999859
# 4           6             11481         5.997081

# %% [markdown]
# ## Popular Tags, Game Details, and Genre

# %%
df[['popular_tags','game_details', 'genre']]
# Out:
#                                             popular_tags  \
# 0      FPS,Gore,Action,Demons,Shooter,First-Person,Gr...
# 1      Survival,Shooter,Multiplayer,Battle Royale,PvP...
# 2      Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# 3      Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# 4      Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
# ...                                                  ...
# 40826                                  Casual,Simulation
# 40827                                  Casual,Simulation
# 40828  RPG,Indie,Strategy,Software,Turn-Based,Fantasy...
# 40829                                             Action
# 40830                                      RPG,Adventure
#
#                                             game_details  \
# 0      Single-player,Multi-player,Co-op,Steam Achieve...
# 1                 Multi-player,Online Multi-Player,Stats
# 2      Single-player,Multi-player,Online Multi-Player...
# 3      Multi-player,Online Multi-Player,Steam Worksho...
# 4      Multi-player,Online Multi-Player,MMO,Co-op,Onl...
# ...                                                  ...
# 40826  Single-player,Shared/Split Screen,Downloadable...
# 40827  Single-player,Shared/Split Screen,Downloadable...
# 40828  Multi-player,Co-op,Cross-Platform Multiplayer,...
# 40829  Single-player,Downloadable Content,Steam Achie...
# 40830  Single-player,Partial Controller Support,Profi...
#
#                                                    genre
# 0                                                 Action
# 1                 Action,Adventure,Massively Multiplayer
# 2                              Action,Adventure,Strategy
# 3                 Action,Adventure,Massively Multiplayer
# 4      Action,Free to Play,Massively Multiplayer,RPG,...
# ...                                                  ...
# 40826                                  Casual,Simulation
# 40827                                  Casual,Simulation
# 40828                                 Indie,RPG,Strategy
# 40829                                             Action
# 40830                                      Adventure,RPG
#
# [40831 rows x 3 columns]

# %% [markdown]
# I want to minimize the abusive of data from a game and the originality of the data of a game. Column `popular_tags` and `genre` have similar meaning. Column `genre` is originated from the developer/publisher of the game, meanwhile `popular_tags` originated from users/players who reviewed it. I do believe that users/players who reviewed the game have the knowledge of the game which they reviewed, but to be fair for I to calculate the similarity of the games, I believe only using `genre` column is suffice enough to calculating similarity between games. So, for this project I only use `genre` column instead of `popular_tags` to identify the genre of the game.

# %% [markdown]
# ## Used Features

# %% [markdown]
# Next I made a dataframe using only columns that needed in identify similarity between games.

# %%
used_col = ["name", "game_details", "genre","weighted_rating","description_clean"]

# %%
df_fix = df[used_col]
df_fix = df_fix.fillna("")

# %% [markdown]
# Before finding similarity, I need to handle null data. If the `name` column is null or empty, I will exclude this game to the modelling because I can't identify which game is this. If the `description_clean` is null or empty and one of `game_details` and `genre` columns are empty or null, I will also exclude the game because I assume this game does not have enough information to find the similarity with other games.

# %%
null_index = []
for i in range(len(df_fix)):
    if df_fix["name"][i]=="":
        null_index.append(i)
    elif (df_fix["description_clean"][i]=="") & ((df_fix["game_details"][i]=="") or (df_fix["genre"][i]=="")):
        null_index.append(i)
    else:
        pass

# %%
#drop null index
df_fix = df_fix.drop(null_index)
df_fix = df_fix.reset_index()

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Computing Cosine Similarity

# %% [markdown]
# I combine the three similarity identifier to be calculated in TF-IDF Vectorizer

# %%
df_fix["concat"] = df_fix["description_clean"] + df_fix["game_details"] + df_fix["genre"]

# %%
#Define a TF-IDF Vectorizer Object
tfidf = TfidfVectorizer()
#Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_matrix = tfidf.fit_transform(df_fix['concat'])

# %%
# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
print(cosine_sim)
# Out:
# [[1.00000000e+00 4.95398031e-02 5.23689211e-02 ... 5.90949957e-02
#   1.91085196e-03 8.87697748e-02]
#  [4.95398031e-02 1.00000000e+00 2.95703606e-02 ... 9.73667037e-03
#   1.98173450e-04 4.44145755e-02]
#  [5.23689211e-02 2.95703606e-02 1.00000000e+00 ... 2.69560804e-02
#   2.41814218e-03 4.67803457e-02]
#  ...
#  [5.90949957e-02 9.73667037e-03 2.69560804e-02 ... 1.00000000e+00
#   3.41772894e-03 3.72617069e-02]
#  [1.91085196e-03 1.98173450e-04 2.41814218e-03 ... 3.41772894e-03
#   1.00000000e+00 4.49253866e-03]
#  [8.87697748e-02 4.44145755e-02 4.67803457e-02 ... 3.72617069e-02
#   4.49253866e-03 1.00000000e+00]]

# %%
indices_id = pd.Series(df_fix.index, index = df_fix['name']).drop_duplicates()

# %% [markdown]
# ## Content Based Recommendation Function

# %%
def get_recommendations(game_name, cosine_sim=cosine_sim, df=df_fix[['name', 'weighted_rating']]):
    
    # Get the index
    idx = indices_id[game_name]
    
    # Get the pairwise similarity scores
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Sort based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
 
    idx_list = []    
    for i in sim_scores:
        idx_game = i[0]
        idx_list.append(idx_game)
    
    # Get the scores of the 20 most similar games
    sim_scores = idx_list[1:21]
    
    # Sort based on the scores
    final_scores = df["weighted_rating"][sim_scores]
    final_scores = list(final_scores.sort_values(ascending=False).index)
    final_scores = final_scores[1:16]
    
    # get the indices
    pr_indices = [i for i in final_scores]
    
    # return the top 10 most similar programs
    return df.iloc[pr_indices]

# %% [markdown]
# ## The Example Result

# %%
get_recommendations("DOOM")
# Out:
#                                name  weighted_rating
# 838             Doom 3: BFG Edition         7.982834
# 579                          DOOM 3         7.979940
# 1421               Victor Vran ARPG         7.979812
# 8639                   Reflex Arena         7.957237
# 7679       The Haunted: Hells Reach         7.870365
# 7772                         HordeZ         7.857986
# 2103    DOOM 3 Resurrection of Evil         7.846152
# 1650           Hell is Other Demons         6.111444
# 5638   RPG World - Action RPG Maker         5.915305
# 35749           Gone with the Demon         5.258431
# 787                        DOOM VFR         4.978265
# 27054    Hunted: The Demon’s Forge™         4.959415
# 30930                     Ice Demon         2.646078
# 39911                     Hellbound         2.646078
# 38046     The World 3:Rise of Demon         2.646078

# %%
get_recommendations("Ni no Kuni™ II: Revenant Kingdom")
# Out:
#                                                     name  weighted_rating
# 25344     Ni no Kuni™ II: Revenant Kingdom - Season Pass         4.488278
# 27045  Ni no Kuni™ II: REVENANT KINGDOM - The Lair of...         4.411519
# 12204                   Wailing Heights Complete Edition         2.646078
# 20279                      Dogenzaka Lab Otome Games set         2.646078
# 6691      The Men of Yoshiwara: Kikuya and Ohgiya Bundle         2.646078
# 7158                   Cloak and Dagger Games Collection         2.646078
# 37214   How to Fool a Liar King - Insert Song "Issho ni"         2.646078
# 23825                        InnerSpace - Digital Deluxe         2.646078
# 22630                 Rising Islands Collector's Edition         2.646078
# 12660                     Wailing Heights Deluxe Edition         2.646078
# 9353                      The Wardrobe - Complete Bundle         2.646078
# 8830               Wandersong Game + Complete Soundtrack         2.646078
# 7162                            Never Again + Soundtrack         2.646078
# 21590                               On The Path Full Set         2.646078
# 7081                         Reigns: Collector's Edition         2.646078

# %%
get_recommendations("EVE Online")
# Out:
#                                        name  weighted_rating
# 12212               Closers: DLC Collection         2.646078
# 3756                    Hero Siege Complete         2.646078
# 7154               Indie Classics By Antoni         2.646078
# 22556                   Playito Multiplayer         2.646078
# 33917            Faeria Cosmetic DLC Bundle         2.646078
# 22470                         Zombie Bundle         2.646078
# 2726                PRO ANGLER SPORT BUNDLE         2.646078
# 2109            Fishing Planet Lucky Bundle         2.646078
# 19136      Trading cards bundle. All in one         2.646078
# 7840                           Space bundle         2.646078
# 20293                      Christmas Bundle         2.646078
# 25726    Rainbow mercenary and Starter Pack         2.646078
# 12123  Business tour. Great Leaders' Bundle         2.646078
# 5441       World of Warships - 3 Ships Pack         2.646078
# 22746         Ground Forces (All Army DLCs)         2.646078

# %%
get_recommendations("FINAL FANTASY X/X-2 HD Remaster")
# Out:
#                                             name  weighted_rating
# 413                     FINAL FANTASY XIV Online         7.995100
# 2838                          Dreamfall Chapters         7.977061
# 915                            FINAL FANTASY III         7.949586
# 1035                            FINAL FANTASY IV         7.941166
# 8798              FINAL FANTASY XV EPISODE ARDYN         7.843453
# 8368                        The Only Traitor DLC         7.665380
# 883                             FINAL FANTASY VI         5.967564
# 931    DEAD OR ALIVE 5 Last Round: Core Fighters         4.996838
# 1019                       MOBIUS FINAL FANTASY™         4.993408
# 26893              FINAL FANTASY XIV: Stormblood         4.941004
# 28631                             Final Quest II         3.705669
# 32036                YUNA: Sugar hearts and Love         2.646078
# 36123               DFF NT: Garland Starter Pack         2.646078
# 16548                         DFFNT: Season Pass         2.646078
# 32720      DFF NT: Arc Sword, Tidus's 4th Weapon         2.646078

# %% [markdown]
# The recommendation result of the algoriithm, seems good enough. But because I more prefer to find the most similar games first then I sorted by weighted rating, the games that has been recommended are seems not really poplar among gamers. especially the last 5 recommended games. So, maybe it still need an improvement.

# %% [markdown]
# # Notes

# %% [markdown]
# ## Potential of Improvement
# 1. Try another similarity metrix out there. There are similar algorithm like cosine similarity such jaccard similarity, euclidean distance, manhattan distance, etc.
# 2. The data preparation process that I did is one of the rushing process because I did this project only in one day. Perhaps it could be enhanced to be better. The ones that I can think of are text cleaning process, adding data source such as number of players, popularity of the game could be added, and maybe the sorting preference can be based weighted rating first then sort by similarity.
# 3. This data can be given a separate ID to make it easier to identify game recommendations to be analyzed.
# 4. Try another null treatment to the data.

# %% [markdown]
# ## References:
# 1. Steam discussion about rating: https://steamcommunity.com/discussions/forum/0/1744483505466407549/
# 2. IMDb Weighted Rating Formula: https://math.stackexchange.com/questions/169032/understanding-the-imdb-weighted-rating-function-for-usage-on-my-own-website
# 3. Another Content Based Recommendation Project with Same Dataset: https://www.kaggle.com/code/fetenbasak/content-based-recommendation-game-recommender
# 4. About Content Based Recommendation and TF-IDF: https://www.analyticsvidhya.com/blog/2015/08/beginners-guide-learn-content-based-recommender-systems/
# 5. Cosine Similarity Scikit-Learn: https://scikit-learn.org/stable/modules/metrics.html
# 6. Cosine Similarity Explanation: https://builtin.com/machine-learning/cosine-similarity
